# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Read the data from an excel file
X = pd.read_excel("../../data/class.xlsx")

## Access a column
X["First Name"]

## Calculate the mean
X.mean()
# Out:
# /tmp/ipykernel_30998/6025988.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   X.mean()
# Height                   177.105263
# Weight                    82.894737
# Age                       24.947368
# Smoking (cig/day)          1.157895
# Coffee (cups/day)          1.263158
# Drink (drinks/week)        2.631579
# Exercise (hours/week)      3.947368
# dtype: float64

# %%
# Plot a histogram
X.hist()

# plt.show() - do this for non-notebook code
# Out:
# array([[<AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'Smoking (cig/day)'}>,
#         <AxesSubplot:title={'center':'Coffee (cups/day)'}>,
#         <AxesSubplot:title={'center':'Drink (drinks/week)'}>],
#        [<AxesSubplot:title={'center':'Exercise (hours/week)'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# DataFrames
 
X["First Name"] # get a column
X.loc[2] # get a row

# get a cell
X.at[2, "First Name"] # row 2, column 'first name'
X.loc[2].at["First Name"] # row 2, element 'first name' of the series
X.iat[2,0] # row 2, column 1
# Out:
# 'C'

# %%
data = np.random.uniform(size = [3,2])
pd.DataFrame(data, index=["John", "Ali", "Sumi"], columns=["X1", "X2"])
# Out:
#             X1        X2
# John  0.530156  0.093423
# Ali   0.172048  0.543578
# Sumi  0.281745  0.330568

# %%
d = {  "one": pd.Series([1, 2], index=["a", "b"]),
       "two": pd.Series([1, 2, 3], index=["a", "b", "c"])}
pd.DataFrame(d)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  NaN    3

# %%
# estimating a mean by hand!
np.sum(X["Height"])/X["Height"].size
# Out:
# 177.10526315789474

# %%
# The mean height of females
heights = X["Height"]
genders = X["Gender"]

# %%
np.mean(heights[genders=="M"])
# Out:
# 177.72727272727272

# %%
np.mean(heights[genders=="F"])
# Out:
# 176.25

# %%
# predicting genders: simple probability table

X["Gender"].hist()
# Out:
# <AxesSubplot:>

# %%
# predicting weight from height: regression
X["Height"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# predicting height: density estimation
X["Height"].plot.kde()

# %%
# Predicting height from gender: conditional density estimation
X[["Weight", "Gender"]].plot.hist(by=["Gender"])
# Out:
# array([<AxesSubplot:title={'center':'F'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'M'}, ylabel='Frequency'>],
#       dtype=object)

# %%
# predicting height and weight: density estimation
X.plot.scatter(x="Height", y ="Weight")
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
# predicting gender from height: classification
# ?pd.DataFrame.plot
# Out:
# Init signature: pd.DataFrame.plot(data)
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot (DataFrame only)
#     - 'hexbin' : hexbin plot (DataFrame only)
# ...

# %%
X[["Weight", "Gender"]].plot.hist(by=["Gender"])
# Out:
# array([<AxesSubplot:title={'center':'F'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'M'}, ylabel='Frequency'>],
#       dtype=object)

# %%
X[["Height", "Gender"]].
