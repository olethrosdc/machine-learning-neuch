# %% [markdown]
# # Lab 1 - Introduction and the K-Nearest Neighbors Algorithm
#
# In this lab section, we will provide a quick introduction to the NumPy library to develop your own implementation of the K-Nearest Neighbors Algorithm.
#
# Specifically, we will cover the following topics:
#
# 1.  NumPy Library
# 2. Pandas library
# 3. Data visualization using Matplotlib and Seaborn
# 4. Implementation of the K-Nearest Neighbors Algorithm
#
# The theoretical background for the first lab session is covered in the 2nd Chapter of the **"An Introduction to Statistical Learning"** book.
#
# For additional information about the lab structure, please refer to the course's lab description [file](https://github.com/olethrosdc/machine-learning-MSc/blob/main/lab.md).

# %% [markdown]
# # 1. The numpy library
#
# Python is a high-level, interpreted programming language known for its readability and versatility. It is widely used in various domains, including web development, data analysis, machine learning, and scientific computing. Python has a large standard library and a vast ecosystem of third-party libraries and frameworks, making it a powerful tool for a wide range of tasks.
#
# - `numpy`: a fundamental Python package for numerical operations, providing support for arrays and matrices, as well as mathematical functions. You can explore
#       its [API documentation](https://numpy.org/doc/stable/reference/index.html).

# %% [markdown]
# ## Import python libraries

# %%
import numpy as np

# %% [markdown]
# We will now go thought some basic functionality of numpy.
# We advise the students to follow the numpy [User guide](https://numpy.org/doc/stable/user/index.html) for a more complete guide on numpy array

# %%
# 1. let define a numpy array
simple_array_1 = np.array([1,2,3,4,5,6])

# %%
# we can get the shape of an array
print("we can get the shape of the vector")
print("vector:", simple_array_1)
print("Result: ", simple_array_1.shape)
# Out:
# we can get the shape of the vector
# vector: [1 2 3 4 5 6]
# Result:  (6,)

# %% [markdown]
# ## numpy prodice very easy api to make numerical operation

# %% [markdown]
# ### 1. scalar operation

# %%
# 1. add a scalar to the vector
scalar_add_result = simple_array_1 + 1
print("Add 1 to the following numpy array:", simple_array_1)
print("Result: ", scalar_add_result)
# Out:
# Add 1 to the following numpy array: [1 2 3 4 5 6]
# Result:  [2 3 4 5 6 7]

# %%
# 2. multiply with scalar
scalate_mut_result = simple_array_1 * 10
print("We can multiply the following array with 10:", simple_array_1)
print("Result: ", scalate_mut_result)
# Out:
# We can multiply the following array with 10: [1 2 3 4 5 6]
# Result:  [10 20 30 40 50 60]

# %% [markdown]
# ### 2. operation between different numpy arrays
#
# we can also make operation between different numpy vector

# %%
# let define a second array
simple_array_2 = np.array([6,5,4,3,2,1])

# %% [markdown]
# let's make different operation between array

# %%
# subtract two vector
sub_result = simple_array_1 - simple_array_2
print("Subtract two vector:")
print("vector 1:", simple_array_1)
print("vector 2:", simple_array_2)
print("Result:", sub_result)
# Out:
# Subtract two vector:
# vector 1: [1 2 3 4 5 6]
# vector 2: [6 5 4 3 2 1]
# Result: [-5 -3 -1  1  3  5]

# %%
# multiply two vector
mult_result = simple_array_1 * simple_array_2
print("Multiply two vector")
print("vector 1:", simple_array_1)
print("vector 2:", simple_array_2)
print("Result:", mult_result)
# Out:
# Multiply two vector
# vector 1: [1 2 3 4 5 6]
# vector 2: [6 5 4 3 2 1]
# Result: [ 6 10 12 12 10  6]

# %% [markdown]
# we can also combine two vector

# %%
concatenate_array = np.concatenate([simple_array_1, simple_array_2])
print("concatenate")
print("vector 1:", simple_array_1)
print("vector 2:", simple_array_2)
print("Result:")
print(concatenate_array)
# Out:
# concatenate
# vector 1: [1 2 3 4 5 6]
# vector 2: [6 5 4 3 2 1]
# Result:
# [1 2 3 4 5 6 6 5 4 3 2 1]

# %% [markdown]
# or stack two arrays, combining them along a specific axis to form a larger array.

# %%
stack_array = np.stack([simple_array_1, simple_array_2],axis=0)
print("stack array")
print("vector 1:", simple_array_1)
print("vector 2:", simple_array_2)
print("Result:")
stack_array
# Out:
# stack array
# vector 1: [1 2 3 4 5 6]
# vector 2: [6 5 4 3 2 1]
# Result:
# array([[1, 2, 3, 4, 5, 6],
#        [6, 5, 4, 3, 2, 1]])

# %% [markdown]
# ### Indexing
# we can select specific item of the numpy array.

# %%
print("select the second item of numpy")
print("vector 1:", simple_array_1)
print("Result:", simple_array_1[2])
# Out:
# select the second item of numpy
# vector 1: [1 2 3 4 5 6]
# Result: 3

# %%
# select a subset of the vector
print("select a subset of the vector")
print("vector 1:", simple_array_1)
print("Result:", simple_array_1[2:])
# Out:
# select a subset of the vector
# vector 1: [1 2 3 4 5 6]
# Result: [3 4 5 6]

# %% [markdown]
# we can reverse an array

# %%
inverse_simple_array_1 = simple_array_1[::-1]
print("array 1: ", simple_array_1)
print("Inverse array 1: ", inverse_simple_array_1)
# Out:
# array 1:  [1 2 3 4 5 6]
# Inverse array 1:  [6 5 4 3 2 1]

# %% [markdown]
# ### build in numpy method
# numpy provide a variety on different build in method that is very useful for data analyse and create complex operation

# %%
print("We can get the sum of an array")
print("Vector:", simple_array_2)
print("Result:", np.sum(simple_array_2))
# Out:
# We can get the sum of an array
# Vector: [6 5 4 3 2 1]
# Result: 21

# %%
print("We can get the power an array")
print("Vector:", simple_array_2)
print("Result:", np.power(simple_array_2,2))
# Out:
# We can get the power an array
# Vector: [6 5 4 3 2 1]
# Result: [36 25 16  9  4  1]

# %%
np.insert(simple_array_2,1,10)
# Out:
# array([ 6, 10,  5,  4,  3,  2,  1])

# %%
print("We can get the square root of an array")
print("Vector:", simple_array_2)
print("Result:", np.sqrt(simple_array_2))
# Out:
# We can get the square root of an array
# Vector: [6 5 4 3 2 1]
# Result: [2.44948974 2.23606798 2.         1.73205081 1.41421356 1.        ]

# %%
# calculate the mean of an array
print("We can get the mean value of a vector ")
print("Vector:", simple_array_1)
print("Result:", simple_array_1.mean())
# Out:
# We can get the mean value of a vector
# Vector: [1 2 3 4 5 6]
# Result: 3.5

# %%
print("We can get the standard deviation of a vector ")
print("Vector:", simple_array_1)
print("Result:", simple_array_1.std())
# Out:
# We can get the standard deviation of a vector
# Vector: [1 2 3 4 5 6]
# Result: 1.707825127659933

# %% [markdown]
# # 2. The pandas library
#
#
# - `pandas`: is a powerful and versatile library that simplifies the tasks of data manipulation in Python. Pandas is well-suited for working with tabular data, such as spreadsheets or SQL tables.

# %%
#import pandas library

import pandas as pd

# %%
# Calling DataFrame constructor 
df = pd.DataFrame() 

# list of strings 
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks'] 
print('list:', lst) 
# Calling DataFrame constructor on list 
df = pd.DataFrame(lst) 
print('DataFrame:', df)
# Out:
# list: ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']
# DataFrame:         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %% [markdown]
# # 3. The matplotlib and seaborn libraries
#
# - `Matplotlib`:
# Plotting and visualization library for Python. We'll use the pyplot module from matplotlib. As convention, it is often imported as plt.
#
# - `seaborn`:
# An easy-to-use visualizetion library that builds on top of Matplotlib and lets you create beautiful charts with just a few lines of code.

# %%
#import libraries

import matplotlib  
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Line Chart
#
#
# A line chart displays information as a series of data points or markers, Line charts work out of the box with matplotlib. You can have multiple lines in a line chart, change color, change type of line and much more
#
# let's take an examlpe to understand and translate the idea of line chart. Let's consider we have a table representing the velocity of 2 moving object at different instance of time and we want to draw the velocity - time graph.

# %%
## firt , create time list 
time = [0 ,5,10,15,20,25,30]

## create velocity of the first object 
velocity_obj_1 = [10,15,20,20,30,15,0]

## create velocity of the second object 
velocity_obj_2 = [0,12,15,12,20,10,25]

# %% [markdown]
#  Create velocity of the first by the time

# %%
## we use plot function to drow line chart 
plt.plot(time  , velocity_obj_1)

# %% [markdown]
#  Create velocity of the second by the time

# %%
## we use plot function to drow line chart 
plt.plot(time , velocity_obj_2)

# %% [markdown]
# merge the both by using plt.plot 2 times

# %%
## let's merge the 2 velocity of 2 objects by using plt.plot 2 times 
plt.plot(time  , velocity_obj_1)
plt.plot(time  , velocity_obj_2)

# %% [markdown]
# [<matplotlib.lines.Line2D at 0x1aaeba93af0>] , we can remove this line by putting ; at the end of last line , or using show function.

# %%
## let's merge the 2 velocity of 2 objects by using plt.plot 2 times 
plt.plot(time  , velocity_obj_1)
plt.plot(time  , velocity_obj_2);
#plt.show()

# %% [markdown]
# we can add title of our graph by using plt.title() , and customize the size of font by using fontsize attribute

# %%
# we can put title  by using plt.title() , and customize the size of font by using fontsize attribute 
plt.plot(time  , velocity_obj_1)
plt.plot(time  , velocity_obj_2)

# Title
plt.title("velocity of 2 objects " , fontsize = 20 )

plt.show()

# %% [markdown]
# Add legend

# %%
## let's merge both by using plt.plot 2 times 
plt.plot(time  , velocity_obj_1)
plt.plot(time  , velocity_obj_2)

# Title
plt.title("velocity of 2 objects " , fontsize = 20 )

# add legend
plt.legend(["object 1 " , "object 2 "], loc='upper right') ;

# %% [markdown]
# Add x and y label and linewidth of each line

# %%
## let's merge both by using plt.plot 2 times 
plt.plot(time  , velocity_obj_1, linewidth = 3)
plt.plot(time  , velocity_obj_2, linewidth = 3)

# Title
plt.title("velocity of 2 objects " , fontsize = 20 )

# add legend
plt.legend(["object 1 " , "object 2 "], loc='upper left') 

plt.xlabel("Time" , fontsize = 12 )
plt.ylabel("velocity of objects" , fontsize = 12 ) ;

# %% [markdown]
# To make the graph bigger, we use a function called figure

# %%
# graph size 
plt.figure(figsize=(15 , 10 )) # the first attribute is the width and and the second one is the length

## let's merge both by using plt.plot 2 times 
plt.plot(time  , velocity_obj_1, linewidth = 3)
plt.plot(time  , velocity_obj_2, linewidth = 3)

# Title
plt.title("velocity of 2 objects " , fontsize = 20 )

# add legend
plt.legend(["object 1 " , "object 2 "], loc='upper left') 

plt.xlabel("Time" , fontsize = 12 )
plt.ylabel("velocity of objects" , fontsize = 12 ) ;

# %% [markdown]
# More about line chart : https://www.geeksforgeeks.org/line-chart-in-matplotlib-python/ || https://datatofish.com/line-chart-python-matplotlib/

# %% [markdown]
# ### EXAMPLE
#
# let's assume that you have a shop and you have data about your sales in the last 5 years. you want to visualize and know insights about your shop sales statue

# %%
"""
     TO DO:
     - Create a list containant the 5 last years
     - Create a sale list for each year
    Make a nice line chart to visualize your sales - years plot.

"""
# Out:
# '\n     TO DO:\n     - Create a list containant the 5 last years\n     - Create a sale list for each year\n    Make a nice line chart to visualize your sales - years plot.\n\n'

# %% [markdown]
# ## Scatter Plot
#
# In a scatter plot, the values of 2 variables are plotted as points on a 2-dimensional grid. Additonally, you can also use a third variable to determine the size or color of the points. let's do previous example with scatter plot

# %%
# use plt.scatter to create a scatter graph
# c refers to the collor points 
# s refers to size of points  
# alpha refers to color opacity of each point , number of alpha must between 0.1 and 1  
plt.scatter(time , velocity_obj_1 , c= 'r' , s = 100 , alpha= 0.8)
plt.scatter(time , velocity_obj_2 , c= 'k' , s = 100 , alpha= 0.9);
# you can use grid() function to get grid lines
#plt.grid()

# %% [markdown]
# colors in matplotlib : b: blue g: green r: red c: cyan m: magenta y: yellow k: black w: white
#
# More about scatter plot : https://www.w3schools.com/python/matplotlib_scatter.asp

# %% [markdown]
# ## Histogram and Frequency Distribution
#
#
# The histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# For example, let’s say that you have the following data about the age of 100 individuals:

# %%
ages = ages = list(np.random.randint(low=18, high=80, size=100))

plt.figure(figsize=(8 , 6 ))  

# plotting the histogram 
plt.hist(ages , bins= 10 , edgecolor='black')
# bins=10: Divides the age data into 10 intervals (bins)
# edgecolor='black': Adds black borders around the bars to make them more distinct.


# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of 100 Individuals');

# %% [markdown]
# We can do the same thing with seaborn

# %%
# Create a seaborn histogram
sns.histplot(ages, bins=10, kde=False)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of 100 Individuals')

# Show the plot
plt.show()

# %% [markdown]
# ## Box Plot
#
# It displays the distribution of the data based on quartiles and highlights outliers.

# %%
sns.boxplot(x=ages)
plt.xlabel('Age')
plt.title('Box Plot of Ages')
plt.show()

# %% [markdown]
# ## Heatmap
#
# Displays data in a matrix format with color-coding to show values.

# %%
# Create a sample correlation matrix
data = np.random.rand(10, 10)
sns.heatmap(data, annot=False)
plt.title('Heatmap Example')
plt.show()

# %% [markdown]
# ## Bar Plot
#
# Displays categorical data with bars.

# %%
# Generate sample data
categories = ['A', 'B', 'C']
values = [10, 20, 30]

sns.barplot(x=categories, y=values)
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Bar Plot Example')
plt.show()

# %% [markdown]
# # K-Nearest Neighbors Algorithm
#
# In the following we will implement the K-Nearest Neighbors Algorithm.
# First we have to create some data for the algorithm. We can do it using the numpy package

# %% [markdown]
# ## Generate some data points

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import statistics


# Generate normally distributed data with mean 0 and standard deviation 1, 100 samples, 3 classes and 2 features.
n_samples=100
class_prob = [0.33, 0.33, 0.34]
x = np.random.normal(loc = 0.0, scale= 1.0, size = (n_samples, 2))
y = np.random.choice(3, p=class_prob, size=n_samples)


# Convert the feature array `x` to a DataFrame with columns 'feature1' and 'feature2'
x = pd.DataFrame(data=x, columns=['feature1', 'feature2'])

# Convert the target array `y` to a DataFrame with column 'target'
y = pd.DataFrame(data=y, columns=['target'])

# Combine the feature DataFrame and target DataFrame into a single DataFrame
data = pd.concat([x, y], axis=1)

# Display the first few rows of the combined DataFrame
data.head()
# Out:
#    feature1  feature2  target
# 0  0.903975  0.425544       2
# 1  0.168078  0.347597       0
# 2 -0.046063 -0.162488       2
# 3  0.066179  1.543595       0
# 4 -0.228644  1.791795       0

# %% [markdown]
# ## Visualize the  data

# %%
palette = { 0:'green', 1:'blue', 2:'red'}

colors = ['r','darkgreen','b','c','m','y']

# Create a figure with specified size
fig = plt.figure(figsize=(15, 8))

# Create the scatter plot
sns.scatterplot(data=data, x='feature1', y='feature2', hue='target', 
                alpha=0.9, s=250, palette=palette)


# Add legend with proper labels
ax = fig.get_axes()[0]
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, title='Class', title_fontsize='13', loc='upper right')

# Display the plot
plt.show()

# %% [markdown]
# ## Randomly create a new data point or test data

# %%
# Generate a random value for x1 within the range of feature1
x1 = random.uniform(data.feature1.min(), data.feature1.max())

# Generate a random value for x2 within the range of feature2
x2 = random.uniform(data.feature2.min(), data.feature2.max())

# Create the test point
test_data = np.array([x1, x2])

# Create the scatter plot
fig = plt.figure(figsize=(15, 8))
sns.scatterplot(data=data, x='feature1', y='feature2', hue='target', 
                alpha=0.9, s=250, palette=palette)

plt.scatter(x=x1, y=x2, s=250, marker='*', color='k', label='test_data')

# Add legend with proper labels
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels, title='Class', title_fontsize='13', loc='upper right')

# Set titles for x and y axes
plt.xlabel('Feature 1', fontsize=14)
plt.ylabel('Feature 2', fontsize=14)

# Display the plot
plt.show()

# %% [markdown]
# ## KNN Implementation

# %% [markdown]
#  Euclidian distance Implementation
#
# Create a function that calculate the euclidian distance between 2 data point by filling the bellow code.
#
# $$
#  \Large d(x,y) = \sqrt{\sum_{i=1}^{n}(x_i - y_i)^2}
# $$

# %%
def calculate_euclidean_distance(x1,x2, data):
    """
    TO DO
    Calculate the Euclidean distance between a given point and all points in the dataset.
    
    - y_i is the test point (mentionned early)
    - x_i is the data points
    
    - you can use np.linalg.norm(..., axis=1)  which includes squaring the differences, 
    summing them up, and taking the square root
    
    - The output is an array containing the distance between each data point and the test point
    """
    
    return euclidean_distance

# %%
# Uncomment and run the next lines to test your function Test you function 

#distances= calculate_euclidean_distance(x1,x2, data)
#distances

# %% [markdown]
# Find the indices of the k-nearest neighbors of test_data in data_x

# %%
def get_k_nearest_neighbors(euclidean_distances, k):
    """
    TO DO
    Get the indices of the k-nearest neighbors based on sorted distances.
    
    You can use np.argsort() of the euclidean_distances
    """
    
    return sorted_indices[:k]

# %%
# Uncomment and run the next lines to test your function Test you function

#k_nearest_indices = get_k_nearest_neighbors(distances, k=5)
#k_nearest_indices

# %% [markdown]
# plot the nearest points

# %%
def plot_knn(data, k, x1, x2, k_nearest_indices):
    """
    Plot the dataset, highlighting the k-nearest neighbors and the test point.
    """
    # Plot the entire dataset
    fig = plt.figure(figsize=(15, 8))
    sns.scatterplot(data=data, x='feature1', y='feature2', hue='target', 
                    alpha=0.9, s=250, palette=palette)

    # Highlight the k-nearest neighbors
    for i in k_nearest_indices:
        plt.scatter(x=data['feature1'][i], y=data['feature2'][i], s=250, alpha=0.6, linewidth=2, edgecolor='k',
                    color='orange')

    # Highlight the test point
    plt.scatter(x=x1, y=x2, s=400, marker='*', color='k')
    
    plt.title(f'K-Nearest Neighbor with K = {k}', fontsize=14)
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend(title='Target')
    plt.show()

# %% [markdown]
# Put everything in one function and Predict the class of the test data_x based on k-nearest neighbors

# %%
def knn_algorithm(data, k, x1, x2):
    """
    TO DO
    Perform K-Nearest Neighbors algorithm and plot the results.
    """
    #TO DO Compute the euclidean distances
    euclidean_distances = 
    
    # TO DO Get k-nearest neighbors
    k_nearest_indices = ?
    
    # Determine the most common label among the k-nearest neighbors
    nearest_labels = data['target'].iloc[k_nearest_indices]
    prediction = statistics.mode(nearest_labels)
    
    # TO DO Plot the results
    ??
    
    return f'Predicted label: {prediction}'
# Out:
#   Cell In[100], line 7
#     euclidean_distances =
#                           ^
# SyntaxError: invalid syntax

# %%
# Test your funtion here and determine the predicted class, You can test with different values of k and analyze.

#predicted_class= knn_algorithm(data, k=5, x1=x1, x2=x2)
#print(predicted_class)
