# %% [markdown]
# # Lab 7 -  SVM
#
# In current lab we will study the Support Vector Machine Classifier using the lab of the ["An Introduction to Statistical Learning"](https://www.statlearning.com/) book.
#
# The original lab can be found in the book [GitHub](https://github.com/intro-stat-learning/ISLP_labs/blob/stable/Ch09-svm-lab.ipynb), while a demonstration of the lab is also available in chapter 9 of the [book](https://hastie.su.domains/ISLP/ISLP_website.pdf.download.html).

# %% [markdown]
# ### Install ISLP library
# Before we start we can download the library of the book that contain some useful utilities tools for the current lab.

# %%
# !pip install ISLP==0.3.20
# Out:
# Requirement already satisfied: ISLP==0.3.20 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (0.3.20)
# Requirement already satisfied: pytorch-lightning in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (2.1.1)
# Requirement already satisfied: pandas<=1.9,>=0.20 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (1.5.2)
# Requirement already satisfied: scipy>=0.9 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (1.11.3)
# Requirement already satisfied: lifelines in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (0.27.8)
# Requirement already satisfied: statsmodels>=0.13 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (0.14.0)
# Requirement already satisfied: pygam in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (0.9.0)
# Requirement already satisfied: torchmetrics in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (1.2.0)
# Requirement already satisfied: joblib in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (1.2.0)
# Requirement already satisfied: lxml in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (4.9.3)
# Requirement already satisfied: numpy<1.25,>=1.7.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (1.24.4)
# Requirement already satisfied: torch in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (2.1.0)
# Requirement already satisfied: scikit-learn>=1.2 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from ISLP==0.3.20) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pandas<=1.9,>=0.20->ISLP==0.3.20) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pandas<=1.9,>=0.20->ISLP==0.3.20) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from scikit-learn>=1.2->ISLP==0.3.20) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from statsmodels>=0.13->ISLP==0.3.20) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from statsmodels>=0.13->ISLP==0.3.20) (22.0)
# Requirement already satisfied: formulaic>=0.2.2 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from lifelines->ISLP==0.3.20) (0.6.6)
# Requirement already satisfied: autograd>=1.5 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from lifelines->ISLP==0.3.20) (1.6.2)
# Requirement already satisfied: autograd-gamma>=0.3 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from lifelines->ISLP==0.3.20) (0.5.0)
# Requirement already satisfied: matplotlib>=3.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from lifelines->ISLP==0.3.20) (3.6.2)
# Requirement already satisfied: progressbar2<5.0.0,>=4.2.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pygam->ISLP==0.3.20) (4.2.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pytorch-lightning->ISLP==0.3.20) (2023.10.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pytorch-lightning->ISLP==0.3.20) (0.9.0)
# Requirement already satisfied: PyYAML>=5.4 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pytorch-lightning->ISLP==0.3.20) (6.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pytorch-lightning->ISLP==0.3.20) (4.4.0)
# Requirement already satisfied: tqdm>=4.57.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from pytorch-lightning->ISLP==0.3.20) (4.66.1)
# Requirement already satisfied: networkx in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from torch->ISLP==0.3.20) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from torch->ISLP==0.3.20) (3.1.2)
# Requirement already satisfied: sympy in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from torch->ISLP==0.3.20) (1.12)
# Requirement already satisfied: filelock in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from torch->ISLP==0.3.20) (3.13.1)
# Requirement already satisfied: future>=0.15.2 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from autograd>=1.5->lifelines->ISLP==0.3.20) (0.18.3)
# Requirement already satisfied: wrapt>=1.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from formulaic>=0.2.2->lifelines->ISLP==0.3.20) (1.14.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from formulaic>=0.2.2->lifelines->ISLP==0.3.20) (1.3.0)
# Requirement already satisfied: astor>=0.8 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from formulaic>=0.2.2->lifelines->ISLP==0.3.20) (0.8.1)
# Requirement already satisfied: requests in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (2.28.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (3.8.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines->ISLP==0.3.20) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines->ISLP==0.3.20) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines->ISLP==0.3.20) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines->ISLP==0.3.20) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines->ISLP==0.3.20) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines->ISLP==0.3.20) (4.38.0)
# Requirement already satisfied: six in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.13->ISLP==0.3.20) (1.16.0)
# Requirement already satisfied: python-utils>=3.0.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from progressbar2<5.0.0,>=4.2.0->pygam->ISLP==0.3.20) (3.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from jinja2->torch->ISLP==0.3.20) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from sympy->torch->ISLP==0.3.20) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (4.0.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (1.9.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/lib/python3.9/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP==0.3.20) (2023.7.22)
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/envs/bayesian-fairness/bin/python3.9 -m pip install --upgrade pip' command.

# %% [markdown]
# # Chapter 9

# %% [markdown]
# # Lab: Support Vector Machines
# In this lab, we use the `sklearn.svm` library to demonstrate the support vector machine.
#
# We  import some of our usual libraries.

# %%
import numpy as np
from matplotlib.pyplot import subplots, cm
import sklearn.model_selection as skm
from ISLP import confusion_table

# %% [markdown]
# We also collect the new imports
# needed for this lab.

# %%
from sklearn.svm import SVC
from ISLP.svm import plot as plot_svm
from sklearn.metrics import RocCurveDisplay

# %% [markdown]
# ### Linear Separatable Classes

# %% [markdown]
# To begign we consider a situation in which the two classes are linearly separable.
#
# Then we can find an optimal separating hyperplane using the SVM model.

# %%
rng = np.random.default_rng(1)

X = rng.standard_normal((50, 2))
y = np.array([-1]*25+[1]*25)
X[y==1] += 3.5

fig, ax = subplots(figsize=(6,6))
ax.scatter(X[:,0],
           X[:,1],
           c=y,
           cmap=cm.coolwarm);

# %% [markdown]
# ## Support Vector Classifier
#
# We now use the `SupportVectorClassifier()` function (abbreviated `SVC()`) from `sklearn` to fit the support vector
# classifier for a given value of the parameter `C`.
#
# The `C` argument allows us to generalize the algorithm to non separatable class, by allowing some violation on the contrains of the svm function.
#
# Then `C` is small then:
# 1. The margin are generaly wider
# 2. We allown more margin violations , or missclassified points
#
#
# Then `C` is big then:
# 1. The margin are smaller
# 2. We dont allown margin violations , or missclassified points

# %%
from sklearn.metrics import accuracy_score

svm_ = SVC(C=100.0, kernel='linear')
svm_.fit(X, y)
# Out:
# SVC(C=100.0, kernel='linear')

# %%
y_hat = svm_.predict(X)
print("Accuracy :", accuracy_score(y_hat, y)*100, "%")
# Out:
# Accuracy : 100.0 %

# %% [markdown]
# Our algorithm has 100 % accuracy as our data are linear separatable.
# Accualy this is also true for the logistic regression, but SVM find the hyperplane with the greater margin beetween the points.

# %%
# we can also get the parameters of the hyperplane
svm_.coef_
# Out:
# array([[0.74923451, 1.20829821]])

# %% [markdown]
# The support vector classifier with two features can
# be visualized by plotting values of its *decision function*.
# We have included a function for this in the `ISLP` package (inspired by a similar
# example in the `sklearn` docs).

# %%
fig, ax = subplots(figsize=(8,8))
plot_svm(X,
         y,
         svm_,
         ax=ax)

# %% [markdown]
# We now try a smaller value of `C`.

# %%
svm_ = SVC(C=0.1, kernel='linear').fit(X, y)
y_hat = svm_.predict(X)
print("Accuracy :", accuracy_score(y_hat, y)*100, "%")
# Out:
# Accuracy : 100.0 %

# %% [markdown]
# Using `C=0.1`, we again 100% accurate but allow some margine violation results in a different hyperplane.
# You can observe that we have a different set of support vector and the margin between the two lines are wider.
#
# When we allown some violation we can ignore potential outlier and, so in general it's more stable.

# %%
fig, ax = subplots(figsize=(6,6))
plot_svm(X,
         y,
         svm_,
         ax=ax)

# %% [markdown]
# ###  Non-Linear Separatable Classes
# we move on by creating some overlaping data, witch is posible to party separate using a simple line.

# %%
rng = np.random.default_rng(1)
X = rng.standard_normal((50, 2))
y = np.array([-1]*25+[1]*25)
X[y==1] += 1
fig, ax = subplots(figsize=(6,6))
ax.scatter(X[:,0],
           X[:,1],
           c=y,
           cmap=cm.coolwarm);

# %% [markdown]
# We now fit the classifier.

# %%
svm_linear = SVC(C=100.0, kernel='linear')
svm_linear.fit(X, y)
# Out:
# SVC(C=100.0, kernel='linear')

# %%
fig, ax = subplots(figsize=(6,6))
plot_svm(X,
         y,
         svm_linear,
         ax=ax)

# %% [markdown]
# What if we instead used a smaller value of the cost parameter?

# %%
svm_linear_small = SVC(C=0.1, kernel='linear')
svm_linear_small.fit(X, y)
fig, ax = subplots(figsize=(6,6))
plot_svm(X,
         y,
         svm_linear_small,
         ax=ax)

# %% [markdown]
# With  a smaller value of the cost parameter, we obtain a larger number of support vectors, because the margin is now wider.

# %% [markdown]
# ### Hyperparameter tunning
# In order to get the optimal hyperparameter for the svm we can apply some model selection tenquieqe as we dint with the other algorithms.
#
# Next, we use the cross validation and grid search in order to find the best value for C.

# %%
grid = skm.GridSearchCV(svm_linear,
                        {'C':[0.001,0.01,0.1,1,5,10,100]},
                        cv=10,
                        scoring='accuracy')
grid.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=SVC(C=100.0, kernel='linear'),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 5, 10, 100]},
#              scoring='accuracy')

# %% [markdown]
# We can easily access the cross-validation errors for each of these models
# in  `grid.cv_results_`.
# This prints out a lot of detail, so we extract the accuracy results only.

# %%
import pandas as pd
pd.DataFrame(grid.cv_results_)[["param_C","mean_test_score", "rank_test_score"]]
# Out:
#   param_C  mean_test_score  rank_test_score
# 0   0.001             0.40                7
# 1    0.01             0.56                6
# 2     0.1             0.74                2
# 3       1             0.76                1
# 4       5             0.74                2
# 5      10             0.74                2
# 6     100             0.74                2

# %%
grid.best_params_
# Out:
# {'C': 1}

# %% [markdown]
# We see that  `C=1` results in the highest cross-validation
# accuracy of 0.76, though
# the accuracy is the same for several values of `C`.
# The classifier `grid.best_estimator_` can be used to predict the class
# label on a set of test observations.
# Let’s generate a test data set.

# %%
X_test = rng.standard_normal((20, 2))
y_test = np.array([-1]*10+[1]*10)
X_test[y_test==1] += 1

# %% [markdown]
# Now we predict the class labels of these test observations. Here we
# use the best model selected by cross-validation in order to make the
# predictions.

# %%
best_ = grid.best_estimator_
y_test_hat = best_.predict(X_test)
print("Accuracy on test set:", accuracy_score(y_test_hat, y_test)*100, "%")
# Out:
# Accuracy on test set: 70.0 %

# %% [markdown]
# ###  Non-Linear Separatable  2
# Now contiue by constracting a more complex dataset witch is not posible to get a good perfmomance with a linear model.

# %%
X = rng.standard_normal((200, 2))
X[:100] += 2
X[100:150] -= 2
y = np.array([1]*150+[2]*50)

# %%
(X_train, 
 X_test,
 y_train,
 y_test) = skm.train_test_split(X,
                                y,
                                test_size=0.2,
                                random_state=0)

# %% [markdown]
# Plotting the data makes it clear that the class boundary is indeed non-linear.

# %%
fig, ax = subplots(figsize=(8,8))
ax.scatter(X[:,0],
           X[:,1],
           c=y,
           cmap=cm.coolwarm)

# %% [markdown]
# ### Non-linear kernel
# In order to fit an SVM using a non-linear kernel, we once again use the `SVC()`  estimator.
#
#
# `SVC()` has also a `kernel`  parameter  to spesify the desired kernel.
#
# Some popular options are the :
# 1. The polynomial kernel, (`kernel="poly"`)  with parameter `d`, witch spesify the deegre of the polynomio.
# 2. The rbf kernel (`kernel="rbf"`) with parameter `gamma`.
#
# We first generate some data with a non-linear class boundary, as follows:

# %% [markdown]
# We can fit the training data using the `SVC()`  estimator with a radial kernel and $\gamma=0.5$:

# %%
svm_rbf_1 = SVC(kernel="rbf", gamma=1, C=1)
svm_rbf_1.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=1)

# %% [markdown]
# The plot shows that the resulting SVM has a decidedly non-linear
# boundary.

# %%
fig, ax = subplots(figsize=(8,8))
plot_svm(X_train,
         y_train,
         svm_rbf_1,
         ax=ax)

# %% [markdown]
# We can see from the figure that there are a fair number of training
# errors in this SVM fit.
#
# If we increase the value of `C`, we can reduce the number of training errors.
# However, this comes at the price of a more irregular decision boundary that seems to be at risk of overfitting the data.

# %%
svm_rbf_2 = SVC(kernel="rbf", gamma=1, C=10000)
svm_rbf_2.fit(X_train, y_train)
fig, ax = subplots(figsize=(8,8))
plot_svm(X_train,
         y_train,
         svm_rbf_2,
         ax=ax)

# %% [markdown]
# Intuitevly smaller gamma parameter results to smoother descition function and thus less overfit.
# Bellow we illustrate the effect of increasing the gamma parameter.

# %%
svm_rbf_3 = SVC(kernel="rbf", gamma=5, C=1)
svm_rbf_3.fit(X_train, y_train)
fig, ax = subplots(figsize=(8,8))
plot_svm(X_train,
         y_train,
         svm_rbf_3,
         ax=ax)

# %% [markdown]
# ### Hyperparameter tunning

# %% [markdown]
# So in order to get the best model we have to perfom hyperparameter tunning to select the best setting for our kernel and model parameters

# %% [markdown]
# We can perform cross-validation using `skm.GridSearchCV()`  to select the
# best choice of $\gamma$ and `C` for an SVM with a radial
# kernel:

# %%
grid = skm.GridSearchCV(svm_rbf_3,
                        {'C':[0.1,1,10,100,1000, 10000],
                         'gamma':[0.1, 0.5,1,2,3,4,10]},
                        cv=10,
                        scoring='accuracy');
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# {'C': 1, 'gamma': 0.1}

# %%
pd.DataFrame(grid.cv_results_)[["param_C","mean_test_score", "rank_test_score"]]
# Out:
#    param_C  mean_test_score  rank_test_score
# 0      0.1          0.76250               38
# 1      0.1          0.86875               14
# 2      0.1          0.79375               37
# 3      0.1          0.76250               38
# 4      0.1          0.76250               38
# 5      0.1          0.76250               38
# 6      0.1          0.76250               38
# 7        1          0.91875                1
# 8        1          0.90000                2
# 9        1          0.89375                8
# 10       1          0.88125               13
# 11       1          0.88750               10
# 12       1          0.88750               10
# 13       1          0.82500               27
# 14      10          0.90000                2
# 15      10          0.89375                8
# 16      10          0.88750               10
# 17      10          0.85625               18
# 18      10          0.86250               17
# 19      10          0.86875               14
# 20      10          0.81875               28
# 21     100          0.90000                2
# 22     100          0.90000                2
# 23     100          0.85625               18
# 24     100          0.85625               18
# 25     100          0.83750               24
# 26     100          0.84375               23
# 27     100          0.80000               34
# 28    1000          0.90000                2
# 29    1000          0.85000               21
# 30    1000          0.85000               21
# 31    1000          0.80625               33
# 32    1000          0.81250               30
# 33    1000          0.83750               24
# 34    1000          0.80000               34
# 35   10000          0.90000                2
# 36   10000          0.86875               14
# 37   10000          0.81875               28
# 38   10000          0.81250               30
# 39   10000          0.81250               30
# 40   10000          0.83750               24
# 41   10000          0.80000               34

# %% [markdown]
# The best choice of parameters under five-fold CV is achieved at `C=1`
# and `gamma=0.5`, though several other values also achieve the same
# value.

# %%
best_svm = grid.best_estimator_
fig, ax = subplots(figsize=(8,8))
plot_svm(X_train,
         y_train,
         best_svm,
         ax=ax)

y_hat_test = best_svm.predict(X_test)
print("accucary score:", accuracy_score(y_hat_test, y_test) * 100, "%")
# Out:
# accucary score: 90.0 %

# %% [markdown]
# by perfom hyperparameter tunning we get a smooth desiction boundary that genelise when in our test data.
